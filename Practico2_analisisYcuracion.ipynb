# %% [markdown]
# ## Objetivo y alcance
#
# En esta segunda aproximación (que suele ir de la mano con el análisis exploratorio y visualización) se pretende empezar a transformar el dataset para los primeros experimentos de aprendedores en las siguientes materias.
#
# En este laboratorio el primer gran objetivo va a ser lograr un único dataset con columnas nuevas, que condense toda la información importante para el posterior entrenamiento y aprendizaje que permitirá conocer si algunas de las variables incluidas en el mismo tienen influencia sobre las fallas en el chatbot y la experiencia que los usuarios tienen con el mismo.
#
# Se deberá explorar la base de datos y detectar variables erroneas, o información repetida, para guardarlo en un archivo nuevo luego de haber obtenido el dataset deseado.
#
# [El dataset nuevo se puede encontrar acá](https://drive.google.com/drive/folders/1MfY_PqF4j-qBnT2hvazEvJ55B8vzMlfw?usp=sharing)

# %% [markdown]
# ## Lista de tareas
#
# 0) El dataset ha cambiado de estructura y tamaño! Ahora hay +488698 registros, y ya no existe From_anon y To_anon. En vez de eso hay un conversation id (conv_id), con el cual se puede seguir una conversación teniendo en cuenta que tenemos el dato del SentDate. Familiarizarse con esta estructura corriendo nuevamente los análisis implementados en el práctico anterior de cantidad de mensajes por conversación!
#
# 1) Verificar los tipos de datos detectados por pandas. Asegurar tipo de datos correctos para las variables que son continuas y aquellas que son categóricas. En el caso de no coincidir se deberán modificar la naturaleza de esas variables.
#
# 2) Verificar y asegurar que no existan datos duplicados.
#
# 3) Verificar que no existan caracteres "raros" para los datos de los features "Body". Tip: Pueden hacerlo importando la librería ftfy.badness
#
# 4) A partir de la columna "Body" y las clases que encontraron en el práctico anterior, generar columnas que codifiquen esas categorías para su posterior uso en los próximos prácticos. Tienen que generar al menos cuatro columnas nuevas. Justifiquen la elección de esa generación respecto a posibles problemas para los cuales puedan ser útiles.
#
# 5) Verificar espacios y normalizar los nombres de las features que crean convenientes para un mejor entendimiento de su significado.
#
# 6) Supongamos que necesitamos compartir públicamente todo el dataset y que los features "Body" contienen potencialmente datos sensibles y confidenciales. Elijan y apliquen técnicas de análisis de texto para detectarlas y técnicas de despersonalización para solucionar este aspecto.
#
# 7) Analizar y normalizar los datos faltantes (nulos), si existen.
#
# 8) Outliers: existen valores atípicos en las columnas del dataset? Si las hay, aplicar una solución para normalizar solo esos Outliers.
#
# 9) Guardar el dataset resultante con un nuevo nombre, para trabajarlo más adelante.
#
# # Se evaluarán los siguientes aspectos:
#
# 1- Que se apliquen los conceptos vistos con los profes en el teórico y en el práctico.
#
# 2- Que el entregable no sea solo la notebook. El informe debe tener un mensaje claro y debe presentarse en un formato legible para cualquier tipo de stakeholder. Además, se deberá entregar el dataset trabajado.
#
# 3- Capacidad de Análisis y justificación. Proactividad en la profundización de los análisis.
#
# 4- Criterio para elegir que solución aplicar en cada caso y con qué método implementarla.
#
# 5- Calidad y estilo de código.
#
#
# Deadline tentativo para la entrega 21/06/2022

# %%
import pandas as pd

df_marzo = pd.read_csv("segunda/marzo.csv")
df_febrero = pd.read_csv("logs_febrero_processed.csv")

# %%
len(df_febrero)
# Out:
# 197045

# %%
df_marzo_to_proc = df_marzo.copy()
df = df_febrero.copy()
print(len(df))
# Out:
# 197045

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'From', 'To', 'Hospital', 'Tel_hospital', 'Tel_client',
#        'Body', 'Status', 'SentDate', 'Fecha', 'Dia', 'Mes', 'Hora', 'Messages',
#        'Direction', 'Appointment_msp', 'Appointment', 'Cancellation_msp',
#        'Cancelled', 'consult', 'Consult_Appoint', 'fail_HH_sms', 'Fail_HH',
#        'achieve_HH', 'Got_HH', 'Cupo', 'Full_turnos_obra_social',
#        'No_Relation', 'No_Correlation', 'has_error', 'Error_Interno',
#        'has_error_501', 'Error_501', 'falla_api_externo', 'Falla_Api_Externo',
#        'alta_dni', 'not_DNI', 'issue_name', 'Issue_Name', 'ask_kunan',
#        'Ask_Kunan', 'many_fallbacks_goto_hh', 'Many_Fallbacks_Goto_HH'],
#       dtype='object')

# %%
df.sort_values(by='SentDate',ascending=True)
# Out:
#         Unnamed: 0                     From                       To Hospital  \
# 94068        96428  whatsapp:+5493562526598  whatsapp:+5493515266217    Carra
# 94067        96427  whatsapp:+5493515266217  whatsapp:+5493562526598    Carra
# 94066        96426  whatsapp:+5493515266217  whatsapp:+5493562526598    Carra
# 94065        96425  whatsapp:+5493562526598  whatsapp:+5493515266217    Carra
# 94063        96423  whatsapp:+5493515266217  whatsapp:+5493562526598    Carra
# ...            ...                      ...                      ...      ...
# 193577      200618  whatsapp:+5493564647126  whatsapp:+5493515266217    Carra
# 193576      200617  whatsapp:+5493515266217  whatsapp:+5493564647126    Carra
# 193575      200616  whatsapp:+5493564647126  whatsapp:+5493515266217    Carra
# 193573      200614  whatsapp:+5493515266217  whatsapp:+5493564647126    Carra
# 193574      200615  whatsapp:+5493515266217  whatsapp:+5493564647126    Carra
#
#                    Tel_hospital               Tel_client  \
# 94068   whatsapp:+5493515266217  whatsapp:+5493562526598
# 94067   whatsapp:+5493515266217  whatsapp:+5493562526598
# 94066   whatsapp:+5493515266217  whatsapp:+5493562526598
# 94065   whatsapp:+5493515266217  whatsapp:+5493562526598
# 94063   whatsapp:+5493515266217  whatsapp:+5493562526598
# ...                         ...                      ...
# 193577  whatsapp:+5493515266217  whatsapp:+5493564647126
# 193576  whatsapp:+5493515266217  whatsapp:+5493564647126
# 193575  whatsapp:+5493515266217  whatsapp:+5493564647126
# 193573  whatsapp:+5493515266217  whatsapp:+5493564647126
# 193574  whatsapp:+5493515266217  whatsapp:+5493564647126
#
#                                                      Body    Status  \
# 94068                                Consultar mis turnos  received
# 94067   Tu sesión se ha reinciado por tiempo de inacti...      read
# 94066                         Necesito tu DNI, por favor.      read
# 94065                                          11.899.463  received
# 94063   No encontré ningún turno asociado a la cuenta ...      read
# ...                                                   ...       ...
# 193577                                        Sacar turno  received
# 193576                        Necesito tu DNI, por favor.      read
# 193575                                           53781569  received
# 193573                     ¿Te puedo ayudar con algo más?      read
# 193574  No se encuentra registrado ese DNI en el siste...      read
#
#                          SentDate       Fecha  ...  falla_api_externo  \
# 94068   2022-01-31 21:18:18+00:00  2022-01-31  ...                 []
# 94067   2022-01-31 21:18:19+00:00  2022-01-31  ...                 []
# 94066   2022-01-31 21:18:19+00:00  2022-01-31  ...                 []
# 94065   2022-01-31 21:18:34+00:00  2022-01-31  ...                 []
# 94063   2022-01-31 21:18:37+00:00  2022-01-31  ...                 []
# ...                           ...         ...  ...                ...
# 193577  2022-02-28 20:43:11+00:00  2022-02-28  ...                 []
# 193576  2022-02-28 20:43:12+00:00  2022-02-28  ...                 []
# 193575  2022-02-28 20:43:25+00:00  2022-02-28  ...                 []
# 193573  2022-02-28 20:43:30+00:00  2022-02-28  ...                 []
# 193574  2022-02-28 20:43:30+00:00  2022-02-28  ...                 []
#
#         Falla_Api_Externo                                           alta_dni  \
# 94068                   0                                                 []
# 94067                   0                                                 []
# 94066                   0                                                 []
# 94065                   0                                                 []
# 94063                   0                                                 []
# ...                   ...                                                ...
# 193577                  0                                                 []
# 193576                  0                                                 []
# 193575                  0                                                 []
# 193573                  0                                                 []
# 193574                  0  ['no se encuentra registrado ese dni en el sis...
#
#         not_DNI issue_name Issue_Name  ask_kunan Ask_Kunan  \
# 94068         0         []          0         []         0
# 94067         0         []          0         []         0
# 94066         0         []          0         []         0
# 94065         0         []          0         []         0
# 94063         0         []          0         []         0
# ...         ...        ...        ...        ...       ...
# 193577        0         []          0         []         0
# 193576        0         []          0         []         0
# 193575        0         []          0         []         0
# 193573        0         []          0         []         0
# 193574        1         []          0         []         0
#
#         many_fallbacks_goto_hh Many_Fallbacks_Goto_HH
# 94068                       []                      0
# 94067                       []                      0
# 94066                       []                      0
# 94065                       []                      0
# 94063                       []                      0
# ...                        ...                    ...
# 193577                      []                      0
# 193576                      []                      0
# 193575                      []                      0
# 193573                      []                      0
# 193574                      []                      0
#
# [197045 rows x 43 columns]

# %%
#df[['Tel_hospital','Tel_client']].value_counts(ascending=True).reset_index(name='conv_id')

columns = ['Tel_hospital','Tel_client']
df['counts'] = pd.Series(zip(*[df.Tel_hospital,df.Tel_client]))
df['conv_id'] = df['counts']#.map(df['counts'].value_counts())


#df_new2 = pd.DataFrame(df['count'].value_counts().reset_index())
#df_new['Tel_hospital'], df_new['Tel_client'] = zip(*df_new['index'])
#df_new = df_new.drop(columns='index')#[['Tel_hospital','Tel_client','count']]

# %%
print("CANTIDAD DE CONV: ", len(df["counts"].unique()))
# Out:
# CANTIDAD DE CONV:  5307

# %%
df["conv_id"] = df.conv_id.map({x: i for i, x in enumerate(df.counts.unique())})

# %%
df[['Tel_hospital','Tel_client',"conv_id","Body"]][0:60]
# Out:
#                Tel_hospital               Tel_client  conv_id  \
# 0   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 1   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 2   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 3   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 4   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 5   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 6   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 7   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 8   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 9   whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 10  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 11  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 12  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 13  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 14  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 15  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 16  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 17  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 18  whatsapp:+5493515266217  whatsapp:+5493564575204        0
# 19  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 20  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 21  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 22  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 23  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 24  whatsapp:+5491120401203  whatsapp:+5491165677078        2
# 25  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 26  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 27  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 28  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 29  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 30  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 31  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 32  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 33  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 34  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 35  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 36  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 37  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 38  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 39  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 40  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 41  whatsapp:+5492215137770  whatsapp:+5492215345855        3
# 42  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 43  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 44  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 45  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 46  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 47  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 48  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 49  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 50  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 51  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 52  whatsapp:+5492215137770  whatsapp:+5492215742546        4
# 53  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 54  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 55  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 56  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 57  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 58  whatsapp:+5493515266230  whatsapp:+5493541649910        1
# 59  whatsapp:+5493515266230  whatsapp:+5493541649910        1
#
#                                                  Body
# 0   Hola, soy el asistente virtual de Clinica Carr...
# 1   ¡Muchas gracias Elva Ana Durbano !, tu turno d...
# 2                                                  Si
# 3   ¡Muchas gracias! Tus datos son: \n▪️ Sede: Car...
# 4                                                   2
# 5   *Escribe el número de la opción* que quieres e...
# 6                                                  21
# 7   *Escribe el número de la opción* que quieres e...
# 8                                                 132
# 9   *Escribe el número de la opción* que quieres e...
# 10                      Quedaron guardados tus datos.
# 11                                                 Si
# 12  ¡Muchas gracias! Tus datos son:  \n ▪️  Nombre...
# 13                                      5493564435504
# 14  Necesito tu número de teléfono, por favor. Con...
# 15                        Ya te encontrás registrado.
# 16                                            9981957
# 17                        Necesito tu DNI, por favor.
# 18                                        Sacar turno
# 19  Hola, soy el asistente virtual de Salud Consul...
# 20                  Hubo un error, intentá más tarde.
# 21                                                 si
# 22  ¡Muchas gracias! Tus datos son: \n▪️ Sede: Tuc...
# 23                                                  4
# 24                                                NaN
# 25  *Escribe el número de la opción* que quieres e...
# 26                                                 57
# 27  Hola, soy el asistente virtual de Centro Medic...
# 28  Estamos fuera del horario de atención con oper...
# 29  Has seleccionado una práctica que requiere ate...
# 30                      Quiero hablar con un operador
# 31                     ¿Te puedo ayudar con algo más?
# 32  No se encuentra registrado ese DNI en el siste...
# 33                                           47743125
# 34                        Necesito tu DNI, por favor.
# 35                           Es oara mi hija 47743125
# 36                        Necesito tu DNI, por favor.
# 37                                       Por la tarde
# 38                        Necesito tu DNI, por favor.
# 39    Esta atendiendo pablo bizarri los dias viernes?
# 40  Hola, soy el asistente virtual de Centro Medic...
# 41                                               Hola
# 42  Hola, soy el asistente virtual de Centro Medic...
# 43  Estamos fuera del horario de atención con oper...
# 44  Has seleccionado una práctica que requiere ate...
# 45                      Quiero hablar con un operador
# 46  No se encuentra registrado ese DNI en el siste...
# 47                     ¿Te puedo ayudar con algo más?
# 48                                           44725664
# 49                        Necesito tu DNI, por favor.
# 50                                        Sacar turno
# 51  Hola, soy el asistente virtual de Centro Medic...
# 52                                               Hola
# 53  *Escribe el número de la opción* que quieres e...
# 54                                                135
# 55  *Escribe el número de la opción* que quieres e...
# 56                      Quedaron guardados tus datos.
# 57                                                 si
# 58  ¡Muchas gracias! Tus datos son:  \n ▪️  Nombre...
# 59                                      5493541649910

# %%
len(df["conv_id"].unique())
# Out:
# 5307

# %%
df[df["conv_id"]==110].sort_values(by='SentDate',ascending=True)
# Out:
#       Unnamed: 0                     From                       To  Hospital  \
# 3044        3044  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3043        3043  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3042        3042  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3041        3041  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3040        3040  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3039        3039  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3038        3038  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3031        3031  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3030        3030  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3027        3027  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3026        3026  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3025        3025  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3013        3013  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3012        3012  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3011        3011  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3010        3010  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3006        3006  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 3005        3005  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 3001        3001  whatsapp:+5492216404697  whatsapp:+5492215137770  CityBell
# 2999        2999  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
# 2998        2998  whatsapp:+5492215137770  whatsapp:+5492216404697  CityBell
#
#                  Tel_hospital               Tel_client  \
# 3044  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3043  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3042  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3041  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3040  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3039  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3038  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3031  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3030  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3027  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3026  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3025  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3013  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3012  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3011  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3010  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3006  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3005  whatsapp:+5492215137770  whatsapp:+5492216404697
# 3001  whatsapp:+5492215137770  whatsapp:+5492216404697
# 2999  whatsapp:+5492215137770  whatsapp:+5492216404697
# 2998  whatsapp:+5492215137770  whatsapp:+5492216404697
#
#                                                    Body    Status  \
# 3044                                                  .  received
# 3043  Perdón, no te puedo ayudar con eso. Solamente ...      read
# 3042                                        Sacar turno  received
# 3041                        Necesito tu DNI, por favor.      read
# 3040                                          XXXXXXXXX  received
# 3039                        Ya te encontrás registrado.      read
# 3038  Necesito tu número de teléfono, por favor. Con...      read
# 3031                                     XXXXXXXXXXXXXX  received
# 3030  ¡Muchas gracias! Tus datos son:  \n  XXXXXXXXX...      read
# 3027                                                 Si  received
# 3026                      Quedaron guardados tus datos.      read
# 3025  *Escribe el número de la opción* que quieres e...      read
# 3013                                              143.0  received
# 3012  *Escribe el número de la opción* que quieres e...      read
# 3011                                             1557.0  received
# 3010  *Escribe el número de la opción* que quieres e...      read
# 3006                                                1.0  received
# 3005  ¡Muchas gracias! Tus datos son: \n  Sede: Call...      read
# 3001                                                 Si  received
# 2999   tu turno de TRAUMATOLOGIA ha sido confirmado ...      read
# 2998  Hola, soy el asistente virtual de Centro Medic...      read
#
#                        SentDate       Fecha  ...  issue_name  Issue_Name  \
# 3044  2022-03-02 20:36:59+00:00  2022-03-02  ...          []           0
# 3043  2022-03-02 20:36:59+00:00  2022-03-02  ...          []           0
# 3042  2022-03-02 20:37:14+00:00  2022-03-02  ...          []           0
# 3041  2022-03-02 20:37:15+00:00  2022-03-02  ...          []           0
# 3040  2022-03-02 20:37:23+00:00  2022-03-02  ...          []           0
# 3039  2022-03-02 20:37:25+00:00  2022-03-02  ...          []           0
# 3038  2022-03-02 20:37:26+00:00  2022-03-02  ...          []           0
# 3031  2022-03-02 20:38:00+00:00  2022-03-02  ...          []           0
# 3030  2022-03-02 20:38:01+00:00  2022-03-02  ...          []           0
# 3027  2022-03-02 20:38:07+00:00  2022-03-02  ...          []           0
# 3026  2022-03-02 20:38:07+00:00  2022-03-02  ...          []           0
# 3025  2022-03-02 20:38:07+00:00  2022-03-02  ...          []           0
# 3013  2022-03-02 20:38:42+00:00  2022-03-02  ...          []           0
# 3012  2022-03-02 20:38:43+00:00  2022-03-02  ...          []           0
# 3011  2022-03-02 20:38:52+00:00  2022-03-02  ...          []           0
# 3010  2022-03-02 20:38:54+00:00  2022-03-02  ...          []           0
# 3006  2022-03-02 20:39:26+00:00  2022-03-02  ...          []           0
# 3005  2022-03-02 20:39:26+00:00  2022-03-02  ...          []           0
# 3001  2022-03-02 20:39:32+00:00  2022-03-02  ...          []           0
# 2999  2022-03-02 20:39:35+00:00  2022-03-02  ...          []           0
# 2998  2022-03-02 20:39:35+00:00  2022-03-02  ...          []           0
#
#       ask_kunan  Ask_Kunan many_fallbacks_goto_hh Many_Fallbacks_Goto_HH  \
# 3044         []          0                     []                      0
# 3043         []          0                     []                      0
# 3042         []          0                     []                      0
# 3041         []          0                     []                      0
# 3040         []          0                     []                      0
# 3039         []          0                     []                      0
# 3038         []          0                     []                      0
# 3031         []          0                     []                      0
# 3030         []          0                     []                      0
# 3027         []          0                     []                      0
# 3026         []          0                     []                      0
# 3025         []          0                     []                      0
# 3013         []          0                     []                      0
# 3012         []          0                     []                      0
# 3011         []          0                     []                      0
# 3010         []          0                     []                      0
# 3006         []          0                     []                      0
# 3005         []          0                     []                      0
# 3001         []          0                     []                      0
# 2999         []          0                     []                      0
# 2998         []          0                     []                      0
#
#       From_anon To_anon                                             counts  \
# 3044       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3043       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3042       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3041       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3040       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3039       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3038       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3031       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3030       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3027       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3026       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3025       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3013       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3012       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3011       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3010       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3006       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3005       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 3001       4385    2519  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 2999       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
# 2998       2624    4215  (whatsapp:+5492215137770, whatsapp:+5492216404...
#
#      conv_id
# 3044     110
# 3043     110
# 3042     110
# 3041     110
# 3040     110
# 3039     110
# 3038     110
# 3031     110
# 3030     110
# 3027     110
# 3026     110
# 3025     110
# 3013     110
# 3012     110
# 3011     110
# 3010     110
# 3006     110
# 3005     110
# 3001     110
# 2999     110
# 2998     110
#
# [21 rows x 47 columns]

# %%
df.to_csv("segunda/febrero_w_conv_id.csv")

# %%
df[["From","To","conv_id"]]
# Out:
#                            From                       To  conv_id
# 0       whatsapp:+5493515266217  whatsapp:+5493564506496     24.0
# 1       whatsapp:+5493515266217  whatsapp:+5493564506496    100.0
# 2       whatsapp:+5493515266217  whatsapp:+5493564506496     10.0
# 3       whatsapp:+5493564506496  whatsapp:+5493515266217      1.0
# 4       whatsapp:+5492215137770  whatsapp:+5492216126998      8.0
# ...                         ...                      ...      ...
# 291648  whatsapp:+5492213521418  whatsapp:+5492215137770      NaN
# 291649  whatsapp:+5492215137770  whatsapp:+5492213521418      NaN
# 291650  whatsapp:+5492213521418  whatsapp:+5492215137770      NaN
# 291651  whatsapp:+5491120401203  whatsapp:+5491134086077      NaN
# 291652  whatsapp:+5491134086077  whatsapp:+5491120401203      NaN
#
# [291653 rows x 3 columns]
